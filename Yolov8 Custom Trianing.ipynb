# %% [markdown]
# <a href="https://colab.research.google.com/github/Ngonidzashe-ux/PPEDetectionSystem/blob/main/Yolov8%20Custom%20Trianing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Important Disclaimer**:
# If you have you own custom data set, and you want to prepare it into the right format for Yolo, you should go back and watch this video timestamp 2h 30 to 2h 40: https://www.youtube.com/watch?v=WgPbbWmnXJ8&t=11210s&ab_channel=Murtaza%27sWorkshop-RoboticsandAI

# %%
# !nvidia-smi

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
# !yolo task=detect mode=predict model=yolov8l.pt conf=0.25 source='https://ultralytics.com/images/bus.jpg'
# Out:
# Ultralytics YOLOv8.0.237 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l summary (fused): 268 layers, 43668288 parameters, 0 gradients, 165.2 GFLOPs
#
# ...
# 100% 476k/476k [00:00<00:00, 30.8MB/s]
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/bus.jpg: 640x480 5 persons, 1 bicycle, 1 bus, 111.8ms
# Speed: 11.9ms preprocess, 111.8ms inference, 667.7ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=train model=yolov8l.pt data=../content/drive/MyDrive/Datasets/ConstructionSafety/data.yaml epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.0.237 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
